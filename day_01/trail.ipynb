# %%
x=[1,2,3]
print(type[x])
# Out:
# type[[1, 2, 3]]

# %%
print(5+10)
# Out:
# 15

# %% [markdown]
# what is mutable?
# changable- set,dict, list

# %%
x={"name":"faang"}
x["name"]="neelima"
print(x)
# Out:
# {'name': 'neelima'}

# %%
x=set()
x.add("123")
print(x)
# Out:
# {'123'}

# %%
x=1,2
print(type(x))
# Out:
# <class 'tuple'>

# %% [markdown]
# 1. -set can have different data types
# 2. -set can have different datatypes

# %%
assert 11==11

# %%
x=[1,2,3,4]
print(sum(x))
print(sum(x)/len(x))
# Out:
# 10
# 2.5

# %%
nums =[10,20,30,40]
for index, num in enumerate(nums):
    print(f"index: {index} and num: {num}")
# Out:
# index: 0 and num: 10
# index: 1 and num: 20
# index: 2 and num: 30
# index: 3 and num: 40
